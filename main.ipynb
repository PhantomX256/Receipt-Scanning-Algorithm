# %%
from source.ocr import OCREngine
from source.preprocess import Preprocessor

preprocessor = Preprocessor()
ocr_engine = OCREngine()

# %%
input_image_path = "dataset/restaurant_receipts/1012-receipt.jpg"

# %%
preprocessed_image = preprocessor.run_preprocess(input_image_path)
# Out:
# [2026-01-21 23:31:22]		[INFO]		run_preprocess()@preprocess.py		Loaded Input Image
# [2026-01-21 23:31:26]		[INFO]		run_preprocess()@preprocess.py		Removed Background
# [2026-01-21 23:31:26]		[INFO]		run_preprocess()@preprocess.py		Image converted to grayscale
# [2026-01-21 23:31:26]		[INFO]		run_preprocess()@preprocess.py		Gaussian Blur Applied
# [2026-01-21 23:31:26]		[INFO]		run_preprocess()@preprocess.py		Adaptive Threshold Applied
# [2026-01-21 23:31:26]		[INFO]		run_preprocess()@preprocess.py		Saved Preprocessed Image
# [2026-01-21 23:31:26]		[INFO]		run_preprocess()@preprocess.py		Preprocessing Complete
# [2026-01-21 23:31:26]		[INFO]		wrapper_timer()@timer.py		Finished run_preprocess() in 3.4016 secs

# %%
ocr_text = ocr_engine.run_ocr(preprocessed_image, input_image_path)
# Out:
# [2026-01-21 23:32:01]		[INFO]		run_ocr()@ocr.py		Performed OCR
# [2026-01-21 23:32:01]		[INFO]		run_ocr()@ocr.py		OCR saved to outputs
# [2026-01-21 23:32:01]		[INFO]		wrapper_timer()@timer.py		Finished run_ocr() in 0.6160 secs
# #14 ,
# HPPhoGa*
# 8930MissionDr.#102
# Rasenead,CA91770
# Phone626288-9999
# Date:AprO1,2019Tine:O5:12PM
# Server:Adnin
# Bill:59980 Table:14
# 1PhoGaSmal1 8.00
# 1PhoGaLarge 9.00
# 1GoiCuon 5.25
# Subtotal 22.25
# TAX 2.11
# Total 24.36
# -$.ServiceCharge40% 8.90
# Total $33.26
# SuggestedTip15%3.85
# , f18x4.38
# 20X-4,87
# OpenTime:Apr01,201904:39PM
# PrintedBy:Admin .
# ThankyouforComing
