# %%
from source.ocr import OCREngine
from source.preprocess import Preprocessor

preprocessor = Preprocessor()
ocr_engine = OCREngine()

# %%
input_image_path = "dataset/walmart_receipts/5.jpg"

# %%
preprocessed_image = preprocessor.run_preprocess(input_image_path)
# Out:
# [2026-01-21 16:35:24]		[INFO]		run_preprocess()@preprocess.py		Loaded Input Image
# [2026-01-21 16:35:33]		[INFO]		run_preprocess()@preprocess.py		Removed Background
# [2026-01-21 16:35:33]		[INFO]		run_preprocess()@preprocess.py		Image converted to grayscale
# [2026-01-21 16:35:33]		[INFO]		run_preprocess()@preprocess.py		Gaussian Blur Applied
# [2026-01-21 16:35:36]		[INFO]		run_preprocess()@preprocess.py		Adaptive Threshold Applied
# [2026-01-21 16:35:37]		[INFO]		run_preprocess()@preprocess.py		Saved Preprocessed Image
# [2026-01-21 16:35:37]		[INFO]		run_preprocess()@preprocess.py		Preprocessing Complete
# [2026-01-21 16:35:37]		[INFO]		wrapper_timer()@timer.py		Finished run_preprocess() in 12.9648 secs

# %%
ocr_text = ocr_engine.run_ocr(preprocessed_image, input_image_path)

print(ocr_text)
# Out:
# [2026-01-21 16:35:39]		[INFO]		run_ocr()@ocr.py		Performed OCR
# [2026-01-21 16:35:39]		[INFO]		run_ocr()@ocr.py		OCR saved to outputs
# [2026-01-21 16:35:39]		[INFO]		wrapper_timer()@timer.py		Finished run_ocr() in 1.5582 secs
# MARKET
# SunnyvaleSVL408-419-1299
# 150EMcKinleyAve
# Sunnyvale,CA94086
# KTTLSEASALTPOTCHP $1.29F
# BRAIDEDBRIOCHE . $6.99F
# CHEFPLATEMEAL$10
# 2 $10.00ea$20.00F
# Subtotal: $28.28 ,
# NetSales: $28.28
# : Total: $28.28
# SoldItems: 4
# Paid: - ye
# Lon Parker
# reopened
# , CPWateDkeeAEd
# RETURNS:Wearenowacceptingreturnson
# purchaseswiththefollowingconditions:
# Returnswillonlybeacceptedonpurchases
# madeonorafter9/15/2020.Allreturns
# requireareceipt.Noreturnsonitems
# purchasedafter90days.Foradditional
# informationpleasevisitwfm.com/returns.
# KKKKKKKKKKKRKKKKKKEKKIEKKKKKKKKKKKKKKEAK
# Earn5%BackatWholeFoodsMarket
# withtheAmazonPrimeRewardsVisa.
# Learnmoreatamazon.com/amazonvisa
# HHRRKKKKKKKRKKKKKRKKKKKEKRIKERK
# HOWWASYOURSHOPPINGEXPERTENCE2
# Goto:http://www.wfm.com/feedback
# ENTERFORACHANCETOWINA$250GIFTCARD
# 908638702/10/202107:10PM
# AAT
# 63011070790806387021020210
# 6KTHOW62ZD
# ThankefarchanningatWhnaleEnadeMarket
