# %%
from source.ocr import OCREngine
from source.preprocess import Preprocessor

preprocessor = Preprocessor()
ocr_engine = OCREngine()

# %%
input_image_path = "dataset/walmart_receipts/10.jpg"

# %%
preprocessed_image = preprocessor.run_preprocess(input_image_path)
# Out:
# [2026-01-21 16:07:58]		[INFO]		run_preprocess()@preprocess.py		Loaded Input Image
# [2026-01-21 16:08:01]		[INFO]		run_preprocess()@preprocess.py		Removed Background
# [2026-01-21 16:08:01]		[INFO]		run_preprocess()@preprocess.py		Image converted to grayscale
# [2026-01-21 16:08:06]		[INFO]		run_preprocess()@preprocess.py		Gaussian Blur Applied
# [2026-01-21 16:08:06]		[INFO]		run_preprocess()@preprocess.py		Adaptive Threshold Applied
# [2026-01-21 16:08:06]		[INFO]		run_preprocess()@preprocess.py		Morphology Applied
# [2026-01-21 16:08:06]		[INFO]		run_preprocess()@preprocess.py		Saved Preprocessed Image
# [2026-01-21 16:08:06]		[INFO]		run_preprocess()@preprocess.py		Preprocessing Complete
# [2026-01-21 16:08:06]		[INFO]		wrapper_timer()@timer.py		Finished run_preprocess() in 8.0755 secs

# %%
ocr_text = ocr_engine.run_ocr(preprocessed_image)

print(ocr_text)
# Out:
# CiveUsfemticksurvey.waleart.cos--7
# Thukyout-10 eeauaristios Ty
# Walmart3,*-22%
# w63-318-0782Morsnae
# 2420CVAESS-GAHRWSBLYD-v..0.o74
# WINTERWAWENEL30634 :
# S0e03347-OPHOKKGILE36TRE080861,
# GYVAIER,,WUZa299191F,,.0.98N i
# eyvatM12*-ooreazoilF.98Msf
# gear WAUF-007874206203F.-:2.04.Nh*
# GEATYAUCOungraatingdF-..2:04Me9
# SAINLEEoosmna7io07..97-F
# cr ec onBamunaress aw, at tak
# SMURFS oreaeDF salva
# GakFSGxupgan0u79308Ft 276
# NieDGuCguaaNOdealE19-28 x
# GERRIESgnaazeuOONeF 1.78Xaooews
# ie Oerasweeee1.97Xay
# tRoIlEGpmGeaITIEH9OT
# BATIERIFSQut2uO0D1/89.5-,10-87-Koys:
# GY2U7WInyO7u747199792as.2.97X
# CHOMYSAUCE007170001605F1-58Opne
# SUREADS---009740026499F-1.:3.460.,
# fous6Cr.:2.-007074212709F-.0.900-s
# SIBIOIA,82.752-2.2
# 17.005.3600
# beepegqarns8FOTALsB6.38wge
# cerclrereje7OLBTETEND,88.35--toy
# - 27canorOUE 0.00
# CRVOeBIE2%5PAYFRON/PRIKARY--
# We.35VOINPURCIMSEyS
# PFIFWMIHHODMUBIEeeseanaeee9602TO
# Rare
# NETwoe1D.-0076APPACODE001740
# tSDedltweeTet
# aC ak escent
# TERATWALTOPNI/21-10:08:22*2sanr/aWt
# #S1tesSOLD18
# voWOF9G9.16733508,0759A7B2
# ray mary
# i I
# LowAitusYuu rust.Every .
# 7 10791721 10:08:26
