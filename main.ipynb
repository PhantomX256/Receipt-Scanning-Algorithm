# %%
from source.ocr import OCREngine
from source.preprocess import Preprocessor

# %%
input_image_path = "dataset/walmart_receipts/10.jpg"

# %%
preprocessor = Preprocessor(clahe=True)

preprocessed_image = preprocessor.run_preprocess(input_image_path)
# Out:
# [2026-01-21 10:54:12]		[INFO]		run_preprocess()@preprocess.py		Loaded Input Image
# [2026-01-21 10:54:12]		[INFO]		run_preprocess()@preprocess.py		Gaussian Blur Applied
# [2026-01-21 10:54:12]		[INFO]		run_preprocess()@preprocess.py		Cropping Receipt
# [2026-01-21 10:54:12]		[INFO]		run_preprocess()@preprocess.py		CLAHE Applied
# [2026-01-21 10:54:12]		[INFO]		run_preprocess()@preprocess.py		Adaptive Threshold Applied
# [2026-01-21 10:54:12]		[INFO]		run_preprocess()@preprocess.py		Morphology Applied
# [2026-01-21 10:54:12]		[INFO]		run_preprocess()@preprocess.py		Saved Preprocessed Image
# [2026-01-21 10:54:12]		[INFO]		run_preprocess()@preprocess.py		Preprocessing Complete

# %%
ocr_engine = OCREngine()

ocr_text = ocr_engine.run_ocr(preprocessed_image)

print(ocr_text)
# Out:
# SOA
