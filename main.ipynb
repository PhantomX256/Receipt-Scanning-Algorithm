# %%
from source.preprocess import Preprocessor

# %%
input_image_path = "dataset/walmart_receipts/0.jpg"

# %%
preprocessor = Preprocessor()

preprocessed_image = preprocessor.run_preprocess(input_image_path)
# Out:
# [2026-01-19 15:26:13]		[INFO]		run_preprocess()@preprocess.py		Loaded Input Image
# [2026-01-19 15:26:13]		[INFO]		run_preprocess()@preprocess.py		Gaussian Blur Applied
# [2026-01-19 15:26:13]		[INFO]		run_preprocess()@preprocess.py		Adaptive Threshold Applied
# [2026-01-19 15:26:13]		[INFO]		run_preprocess()@preprocess.py		Morphology Applied
# [2026-01-19 15:26:13]		[INFO]		run_preprocess()@preprocess.py		Saved Preprocessed Image
# [2026-01-19 15:26:13]		[INFO]		run_preprocess()@preprocess.py		Preprocessing Complete
